# %% [markdown]
# # Northwestern Mutual Community of Analysts Python Lunch and Learn

# %% [markdown]
# # Importing Functionality
#
# In Excel, we have an extensive collection of functions that are ready to use whenever the Excel software is open.
#
# ![image.png](data:image/png;base64,...)
#
# In Python, we only have a handful of [bulit-in functions](https://docs.python.org/3/library/functions.html).
#
# ![image.png](data:image/png;base64,...)
#
# The inclusion of a core set of built-in functions is efficient (computationally, allowing us to use only those functions that are absolutely necessary. However, we will want some extra functionality for data analytic tasks. Fortunately, there are numerous Python **libraries** which provide functionality for a wide variety of tasks. One such library that is extremely popular for data analysis and data wrangling is called [pandas](https://pandas.pydata.org/), the "Python Data Analysis Library". To use pandas in our Python session, we must first **import** the library. Click on the cell below that contains `import pandas` and click on "play" button that appears on the left side of the cell to execute the code within the cell.

# %%
import pandas as pd
